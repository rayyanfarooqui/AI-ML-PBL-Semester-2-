# %%
import pickle 
with open("svm.pkl","rb") as f :
    svmmodel =pickle.load(f)
with open("scaler.pkl", "rb") as f:
    scaler = pickle.load(f)

with open("all_features.pkl", "rb") as f:
    all_features = pickle.load(f)
print("model loaded")

# %%
Unnamed: 0 → 1
loan_amount → 180000
rate_of_interest → 6.8
Interest_rate_spread → 0.2
Upfront_charges → 1200
term → 240
property_value → 400000
income → 80000
Credit_Score → 780
LTV → 45
dtir1 → 25
loan_to_income → 2.2
loan_to_collateral → 0.45
interest_burden → 10000
total_cost_proxy → 200000
risk_score → 0.15
loan_limit_ncf → 1

Gender_Joint → 0
Gender_Male → 1
Gender_Sex Not Available → 0

approv_in_adv_pre → 1

loan_type_type2 → 0
loan_type_type3 → 0

loan_purpose_p2 → 0
loan_purpose_p3 → 1
loan_purpose_p4 → 0

Credit_Worthiness_l2 → 0

business_or_commercial_nob/c → 1

Neg_ammortization_not_neg → 1
interest_only_not_int → 1
lump_sum_payment_not_lpsm → 1

occupancy_type_pr → 1
occupancy_type_sr → 0

total_units_2U → 0
total_units_3U → 0
total_units_4U → 0

credit_type_CRIF → 0
credit_type_EQUI → 1
credit_type_EXP → 0

expected output is 1

# %%
user_data = {}

for feature in all_features:
    val = float(input(f"Enter {feature}: "))
    user_data[feature] = val

# convert to dataframe (VERY IMPORTANT)
user_df = pd.DataFrame([user_data])

# %%
user_scaled = scaler.transform(user_df)

prediction = svmmodel.predict(user_scaled)

if prediction[0] == 1:
    print("Risky Loan (Default)")
else:
    print("Safe Loan")
