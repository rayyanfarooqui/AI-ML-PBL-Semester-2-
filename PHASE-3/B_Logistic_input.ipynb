# %%
import pickle

with open("scaler.pkl", "rb") as f:
    scaler = pickle.load(f)
    
with open("model5.pkl", "rb") as f:
    model5 = pickle.load(f)

with open("model4.pkl", "rb") as f:
    model4 = pickle.load(f)
with open("features.pkl", "rb") as f:
    selected_features = pickle.load(f)

with open("pca.pkl", "rb") as f:
    pca = pickle.load(f)    
    
with open("all_features.pkl" , "rb") as f:
        all_features=pickle.load(f)
print("models loaded")
# Out:
# models loaded

# %%
#Forward/backward selection based model
# ['credit_type_EQUI', 'lump_sum_payment_not_lpsm', 'loan_to_income']
f1 = float(input("Enter value for credit_type_EQUI(enter 1 for yes, 0 for no) :  "))
f2 = float(input("Enter value for Lump_sum_payment_not_lpsm(enter 1 for yes, 0 for no) : "))
f3 = float(input("Enter value for Loan to income : "))

user_input= [[f1, f2, f3]]
user_scaled = scaler.transform(user_input)
prediction= model4.predict(user_scaled)
if prediction[0] == 1:
    print("Risky Loan applicant ")
else:
    print("Safe Loan applicant ")
# Out:
# Enter value for credit_type_EQUI(enter 1 for yes, 0 for no) :   1
# Enter value for Lump_sum_payment_not_lpsm(enter 1 for yes, 0 for no) :  1
# Enter value for Loan to income :  0.2
# Risky Loan applicant
# C:\Users\Tetra\AppData\Roaming\Python\Python312\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %% [raw]
# Unnamed: 0 → 1
# loan_amount → 250000
# rate_of_interest → 7.5
# Interest_rate_spread → 0.3
# Upfront_charges → 2000
# term → 240
# property_value → 400000
# income → 60000
# Credit_Score → 720
# LTV → 62
# Status → (don’t input, this is target ❌)
# dtir1 → 35
# loan_to_income → 4.1
# loan_to_collateral → 0.62
# interest_burden → 18000
# total_cost_proxy → 270000
# risk_score → 0.25
# loan_limit_ncf → 1
#
# Gender_Joint → 0
# Gender_Male → 1
# Gender_Sex Not Available → 0
#
# approv_in_adv_pre → 1
#
# loan_type_type2 → 0
# loan_type_type3 → 0
#
# loan_purpose_p2 → 0
# loan_purpose_p3 → 1
# loan_purpose_p4 → 0
#
# Credit_Worthiness_l2 → 0
#
# business_or_commercial_nob/c → 1
#
# Neg_ammortization_not_neg → 1
# interest_only_not_int → 1
# lump_sum_payment_not_lpsm → 0
#
# occupancy_type_pr → 1
# occupancy_type_sr → 0
#
# total_units_2U → 0
# total_units_3U → 0
# total_units_4U → 0
#
# credit_type_CRIF → 0
# credit_type_EQUI → 1
# credit_type_EXP → 0

# %%
#PCA based model
user_values = []
for f in all_features:   
    val = float(input(f"Enter {f}: "))
    user_values.append(val)
user_scaled = scaler.transform(user_input)
user_pca=pca.transform(user_scaled)
prediction= model.predict(user_pca)
if prediction[0] == 1:
    print("Risky Loan (Default)")
else:
    print("Safe Loan")
# Out:
# Enter value for credit_type_EQUI(enter 1 for yes, 0 for no) :   1
# Enter value for Lump_sum_payment_not_lpsm(enter 1 for yes, 0 for no) :  1
# Enter value for Loan to income :  0.2
# C:\Users\Tetra\AppData\Roaming\Python\Python312\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 9
#       7 user_input= [[f1, f2, f3]]
#       8 user_scaled = scaler.transform(user_input)
# ----> 9 user_pca=pca.transform(user_scaled)
#      10 prediction= model.predict(user_pca)
#      11 if prediction[0] == 1:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sklearn\utils\_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
# ...
