# %%
import pickle 
with open("knnmodel.plk", "rb")as f:
    model=pickle.load(f)
with open("scaler.pkl", "rb") as f:
    scaler = pickle.load(f)

with open("all_features.pkl", "rb") as f:
    all_features = pickle.load(f)   
print("Models loaded ")
# Out:
# Models loaded

# %% [raw]
# #SAMPLE INPUT
# Unnamed: 0 → 1
# loan_amount → 200000
# rate_of_interest → 7.2
# Interest_rate_spread → 0.25
# Upfront_charges → 1500
# term → 240
# property_value → 350000
# income → 55000
# Credit_Score → 710
# LTV → 57
# dtir1 → 32
# loan_to_income → 3.6
# loan_to_collateral → 0.57
# interest_burden → 14000
# total_cost_proxy → 240000
# risk_score → 0.22
# loan_limit_ncf → 1
#
# Gender_Joint → 0
# Gender_Male → 1
# Gender_Sex Not Available → 0
#
# approv_in_adv_pre → 1
#
# loan_type_type2 → 0
# loan_type_type3 → 0
#
# loan_purpose_p2 → 0
# loan_purpose_p3 → 1
# loan_purpose_p4 → 0
#
# Credit_Worthiness_l2 → 0
#
# business_or_commercial_nob/c → 1
#
# Neg_ammortization_not_neg → 1
# interest_only_not_int → 1
# lump_sum_payment_not_lpsm → 0
#
# occupancy_type_pr → 1
# occupancy_type_sr → 0
#
# total_units_2U → 0
# total_units_3U → 0
# total_units_4U → 0
#
# credit_type_CRIF → 0
# credit_type_EQUI → 1
# credit_type_EXP → 0

# %%
user_data = {}

for feature in all_features:
    val = float(input(f"Enter {feature}: "))
    user_data[feature] = val

# convert to DataFrame (IMPORTANT for correct column order)
user_df = pd.DataFrame([user_data])

# %%
user_scaled = scaler.transform(user_df)

prediction = model.predict(user_scaled)

if prediction[0] == 1:
    print("Risky Loan applicant ")
else:
    print("Safe Loan")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 user_scaled = scaler.transform(user_df)
#       3 prediction = model.predict(user_scaled)
#       5 if prediction[0] == 1:
#
# NameError: name 'user_df' is not defined
